# %%
while True:
    print("\nBem-vindo à Calculadora! Escolha as operações abaixo:")
    print("1. Soma")
    print("2. Subtração")
    print("3. Multiplicação")
    print("4. Divisão")
    print("5. Sair")

    escolha = input("Digite o número correspondente à operação desejada: ")

    if escolha == '5':
        print("Encerrando o programa. Até a próxima!")
        break

    if escolha not in ['1', '2', '3', '4']:
        print("Opção inválida. Tente novamente.")
        continue

    try:
        num1 = float(input("Digite o primeiro número: "))
        num2 = float(input("Digite o segundo número: "))
    except ValueError:
        print("Por favor, insira apenas números válidos.")
        continue

    if escolha == '1':
        resultado = num1 + num2
        print(f"Resultado da soma: {resultado}")
    elif escolha == '2':
        resultado = num1 - num2
        print(f"Resultado da subtração: {resultado}")
    elif escolha == '3':
        resultado = num1 * num2
        print(f"Resultado da multiplicação: {resultado}")
    elif escolha == '4':
        if num2 == 0:
            print("Divisão por zero não é permitida.")
        else:
            resultado = num1 / num2
            print(f"Resultado da divisão: {resultado}")
# Out:
# Bem-vindo à Calculadora! Escolha as operações abaixo:
# 1. Soma
# 2. Subtração
# 3. Multiplicação
# 4. Divisão
# 5. Sair
# Resultado da soma: 10.0
#
# Bem-vindo à Calculadora! Escolha as operações abaixo:
# 1. Soma
# 2. Subtração
# 3. Multiplicação
# 4. Divisão
# 5. Sair
# Resultado da soma: 12.0
#
# Bem-vindo à Calculadora! Escolha as operações abaixo:
# 1. Soma
# 2. Subtração
# 3. Multiplicação
# 4. Divisão
# 5. Sair
# Resultado da multiplicação: 25.0
#
# Bem-vindo à Calculadora! Escolha as operações abaixo:
# 1. Soma
# 2. Subtração
# 3. Multiplicação
# 4. Divisão
# 5. Sair
# Opção inválida. Tente novamente.
#
# Bem-vindo à Calculadora! Escolha as operações abaixo:
# 1. Soma
# 2. Subtração
# 3. Multiplicação
# 4. Divisão
# 5. Sair
# Opção inválida. Tente novamente.
#
# Bem-vindo à Calculadora! Escolha as operações abaixo:
# 1. Soma
# 2. Subtração
# 3. Multiplicação
# 4. Divisão
# 5. Sair
# Opção inválida. Tente novamente.
#
# Bem-vindo à Calculadora! Escolha as operações abaixo:
# 1. Soma
# 2. Subtração
# 3. Multiplicação
# 4. Divisão
# 5. Sair
# Opção inválida. Tente novamente.
#
# Bem-vindo à Calculadora! Escolha as operações abaixo:
# 1. Soma
# 2. Subtração
# 3. Multiplicação
# 4. Divisão
# 5. Sair
# Opção inválida. Tente novamente.
#
# Bem-vindo à Calculadora! Escolha as operações abaixo:
# 1. Soma
# 2. Subtração
# 3. Multiplicação
# 4. Divisão
# 5. Sair
# Opção inválida. Tente novamente.
#
# Bem-vindo à Calculadora! Escolha as operações abaixo:
# 1. Soma
# 2. Subtração
# 3. Multiplicação
# 4. Divisão
# 5. Sair
# Opção inválida. Tente novamente.
#
# Bem-vindo à Calculadora! Escolha as operações abaixo:
# 1. Soma
# 2. Subtração
# 3. Multiplicação
# 4. Divisão
# 5. Sair
# Opção inválida. Tente novamente.
#
# Bem-vindo à Calculadora! Escolha as operações abaixo:
# 1. Soma
# 2. Subtração
# 3. Multiplicação
# 4. Divisão
# 5. Sair
# Opção inválida. Tente novamente.
#
# Bem-vindo à Calculadora! Escolha as operações abaixo:
# 1. Soma
# 2. Subtração
# 3. Multiplicação
# 4. Divisão
# 5. Sair
